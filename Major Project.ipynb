# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('test.csv')

# %%
data.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# 1                  5              0            0                  51
# 2                  4              0            0                  47
# 3                  9              0            0                  65
# 4                  7              0            0                  61

# %%
data.shape
# Out:
# (23490, 13)

# %%
data.tail()
# Out:
#        employee_id   department     region         education gender  \
# 23485        53478        Legal   region_2   Below Secondary      m
# 23486        25600   Technology  region_25        Bachelor's      m
# 23487        45409           HR  region_16        Bachelor's      f
# 23488         1186  Procurement  region_31        Bachelor's      m
# 23489         5973   Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 23485            sourcing                1   24                   3.0
# 23486            sourcing                1   31                   3.0
# 23487            sourcing                1   26                   4.0
# 23488            sourcing                3   27                   NaN
# 23489               other                3   40                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 23485                  1              0            0                  61
# 23486                  7              0            0                  74
# 23487                  4              0            0                  50
# 23488                  1              0            0                  70
# 23489                  5              1            0                  89

# %%
data.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  23490.000000     23490.000000  23490.000000          21678.000000
# mean   39041.399149         1.254236     34.782929              3.339146
# std    22640.809201         0.600910      7.679492              1.263294
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19370.250000         1.000000     29.000000              3.000000
# 50%    38963.500000         1.000000     33.000000              3.000000
# 75%    58690.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score
# count       23490.000000   23490.000000  23490.000000        23490.000000
# mean            5.810387       0.358834      0.022776           63.263133
# std             4.207917       0.479668      0.149191           13.411750
# min             1.000000       0.000000      0.000000           39.000000
# 25%             3.000000       0.000000      0.000000           51.000000
# 50%             5.000000       0.000000      0.000000           60.000000
# 75%             7.000000       1.000000      0.000000           76.000000
# max            34.000000       1.000000      1.000000           99.000000

# %%
data.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score'],
#       dtype='object')

# %%
data.nunique()
# Out:
# employee_id             23490
# department                  9
# region                     34
# education                   3
# gender                      2
# recruitment_channel         3
# no_of_trainings             9
# age                        41
# previous_year_rating        5
# length_of_service          34
# KPIs_met >80%               2
# awards_won?                 2
# avg_training_score         61
# dtype: int64

# %%
data['department'].unique()
# Out:
# array(['Technology', 'HR', 'Sales & Marketing', 'Procurement', 'Finance',
#        'Analytics', 'Operations', 'Legal', 'R&D'], dtype=object)

# %%
data['age'].unique()
# Out:
# array([24, 31, 30, 36, 33, 51, 29, 40, 34, 37, 26, 49, 27, 25, 41, 52, 43,
#        35, 42, 57, 46, 21, 32, 28, 38, 23, 58, 54, 44, 48, 45, 39, 59, 53,
#        56, 47, 22, 20, 50, 55, 60], dtype=int64)

# %%
#cleaning the data
data.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
employee = data.drop(['gender','region'], axis=1)

# %%
employee.head()
# Out:
#    employee_id         department   education recruitment_channel  \
# 0         8724         Technology  Bachelor's            sourcing
# 1        74430                 HR  Bachelor's               other
# 2        72255  Sales & Marketing  Bachelor's               other
# 3        38562        Procurement  Bachelor's               other
# 4        64486            Finance  Bachelor's            sourcing
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   24                   NaN                  1
# 1                1   31                   3.0                  5
# 2                1   31                   1.0                  4
# 3                3   31                   2.0                  9
# 4                1   30                   4.0                  7
#
#    KPIs_met >80%  awards_won?  avg_training_score
# 0              1            0                  77
# 1              0            0                  51
# 2              0            0                  47
# 3              0            0                  65
# 4              0            0                  61

# %%
#relationship anaylsis

# %%
corelation = employee.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-1f643fa33488> in <module>
# ----> 1 sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
#
# AttributeError: 'function' object has no attribute 'columns'

# %%
sns.pairplot(employee)

# %%
sns.relplot(x= 'education', y='age', data=employee)

# %%
sns.heatmap(data.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>
